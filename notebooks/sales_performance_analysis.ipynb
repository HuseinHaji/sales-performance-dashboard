# %% [markdown]
# # Sales Performance Dashboard
# This notebook provides an overview of synthetic sales performance outputs.

# %%
import pandas as pd
from pathlib import Path
BASE = Path("/Users/huseyn/Desktop/sales-performance-dashboard")
df = pd.read_csv(BASE / "data" / "powerbi" / "monthly_kpi_summary.csv")
df.head()
